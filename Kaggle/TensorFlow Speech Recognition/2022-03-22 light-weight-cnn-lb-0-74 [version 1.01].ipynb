# %% [markdown]
# ## Preface
#
# 이 노트는 가벼운 CNN을 만드는 것을 목표로 합니다.
#
# 재샘플링된 wav 파일의 스펙그램(rate 8000)을 입력으로 사용합니다.
#
# Kaggle 클라우드 하드웨어 제한으로 인해 이 스크립트는 원래 스크립트의 '크립' 버전입니다.
#
# LB 0.74를 얻으려면 epoch를 5로 설정하고 chop_pairs(num=1000)를 설정하고 모든 Conv 계층 매개 변수를 두 배로 해야 합니다.
#
# 이 스크립트는 Alex Ozerin의 기준보다 약간 개선된 것이지만, 원본 wav 파일(16000 샘플링 속도)을 사용하면 더 높은 점수를 얻을 수 있다고 생각합니다.
#
#
# ## File Structure
#
# 이 스크립트는 데이터가 다음 구조에 저장되어 있다고 가정합니다.
#
# speech
#
# ├── test
#
# │   └── audio #test wavfiles
#
# ├── train
#
# │   ├── audio #train wavfiles
#
# └── model #store models
#
# │
#
# └── out #store sub.csv
#
#
# ## Improve This Script
# 이것은 단지 가벼운 CNN이기 때문에 성능이 제한적입니다.
# 다음은 성능을 개선할 수 있는 몇 가지 방법입니다.
#
# 1. 재샘플링된 파일 대신 원본 wav 파일을 사용합니다.
# 2. chop_audio를 사용하여 더 많은 '사일런트' wav 파일을 만듭니다.
# 3. 더 깊은 CNN, RNN을 사용합니다.
# 4. 더 긴 epoch을 위해 훈련합니다.

# %%
import os
import numpy as np
import pandas as pd

from scipy.fftpack import fft
from scipy.io import wavfile
from scipy import signal
from glob import glob # glob는 파일들의 리스트를 뽑을 때 사용하는데, 파일의 경로명을 이용해서 입맛대로 요리할 수 있답니다.
import re
import gc # 직접 할당/해제하지 않아도 객체가 현재 쓰이는곳이 없을 경우 자동으로 해제

from keras import optimizers, losses, activations, models
from keras.layers import Convolution2D, Dense, Input, Flatten, Dropout, MaxPooling2D, BatchNormalization
from sklearn.model_selection import train_test_split
import keras

# %% [markdown]
# 원래 샘플링 속도는 16000이며 데이터 크기를 줄이기 위해 8000으로 다시 샘플링하겠습니다.

# %%
L = 16000
legal_labels = 'yes no up down left right on off stop go silence unknown'.split()

#src folders
root_path = r'.'
out_path = r'.'
model_path = r'.'
train_data_path = os.path.join(root_path, 'input', 'train', 'train','audio')
test_data_path = os.path.join(root_path, 'input', 'test', 'audio')

# %%
legal_labels = 'yes no up down left right on off stop go silence unknown'.split()
legal_labels
# Out:
# ['yes',
#  'no',
#  'up',
#  'down',
#  'left',
#  'right',
#  'on',
#  'off',
#  'stop',
#  'go',
#  'silence',
#  'unknown']

# %%
root_path = r'.'
root_path
# Out:
# '..'

# %%
def custom_fft(y, fs):
    T = 1.0 / fs
    N = y.shape[0]
    yf = fft(y)
    xf = np.linspace(0.0, 1.0/(2.0*T), N//2)
    # FFT is simmetrical, so we take just the first half
    # FFT is also complex, to we take just the real part (abs)
    vals = 2.0/N * np.abs(yf[0:N//2])
    return xf, vals

def log_specgram(audio, sample_rate, window_size=20,
                 step_size=10, eps=1e-10):
    nperseg = int(round(window_size * sample_rate / 1e3))
    noverlap = int(round(step_size * sample_rate / 1e3))
    freqs, times, spec = signal.spectrogram(audio,
                                    fs=sample_rate,
                                    window='hann',
                                    nperseg=nperseg,
                                    noverlap=noverlap,
                                    detrend=False)
    return freqs, times, np.log(spec.T.astype(np.float32) + eps)

# %% [markdown]
# 다음은 train 데이터 폴더 내의 모든 wav 파일을 캡처하는 유틸리티 기능입니다.

# %%
def list_wavs_fname(dirpath, ext='wav'):
    print(dirpath)
    fpaths = glob(os.path.join(dirpath, r'*/*' + ext))
    pat = r'.+/(\w+)/\w+\.' + ext + '$'
    
    labels = []
    for fpath in fpaths:
        r = re.match(pat, fpath) # re.match 함수는“문자열의 처음”부터 시작하여 패턴이 일치되는 것이 있는지를 확인한다.
_nohash_0.wav',
#  '.\\input\\train\\train\\audio\\bed\\8781f4c1_nohash_1.wav',
#  '.\\input\\train\\train\\audio\\bed\\87c62767_nohash_0.wav',
#  '.\\input\\train\\train\\audio\\bed\\87eff300_nohash_0.wav',
#  '.\\input\\train\\train\\audio\\bed\\88120683_nohash_0.wav',
#  '.\\input\\train\\train\\audio\\bed\\881583a6_nohash_0.wav',
#  '.\\input\\train\\train\\audio\\bed\\8830e17f_nohash_0.wav',
#  '.\\input\\train\\train\\audio\\bed\\884ae8e1_nohash_0.wav',
#  '.\\input\\train\\train\\audio\\bed\\888a0c49_nohash_0.wav',
#  '.\\input\\train\\train\\audio\\bed\\88a487ce_nohash_0.wav',
#  '.\\input\\train\\train\\audio\\bed\\88e90bc1_nohash_0.wav',
#  '.\\input\\train\\train\\audio\\bed\\89d6d11e_nohash_0.wav',
#  '.\\input\\train\\train\\audio\\bed\\89ed36ab_nohash_0.wav',
#  '.\\input\\train\\train\\audio\\bed\\89f3ab7d_nohash_0.wav',
#  '.\\input\\train\\train\\audio\\bed\\89f3ab7d_nohash_1.wav',
#  '.\\input\\train\\train\\audio\\bed\\89f680f3_nohash_0.wav',
#  '.\\input\\train\\train\\audio\\bed\\89f680f3_nohash_1.wav',
#  '.\\input\\train\\train\\audio\\bed\\89f680f3_nohash_2.wav',
#  '.\\input\\train\\train\\audio\\bed\\8a0457c9_nohash_0.wav',
#  '.\\input\\train\\train\\audio\\bed\\8a0457c9_nohash_1.wav',
#  '.\\input\\train\\train\\audio\\bed\\8a28231e_nohash_0.wav',
#  '.\\input\\train\\train\\audio\\bed\\8a28231e_nohash_1.wav',
#  '.\\input\\train\\train\\audio\\bed\\8a5acefd_nohash_0.wav',
#  '.\\input\\train\\train\\audio\\bed\\8a744054_nohash_0.wav',
#  '.\\input\\train\\train\\audio\\bed\\8aa35b0c_nohash_0.wav',
#  '.\\input\\train\\train\\audio\\bed\\8aa35b0c_nohash_1.wav',
#  '.\\input\\train\\train\\audio\\bed\\8b39e36f_nohash_0.wav',
#  '.\\input\\train\\train\\audio\\bed\\8b39e36f_nohash_1.wav',
#  '.\\input\\train\\train\\audio\\bed\\8b775397_nohash_0.wav',
#  '.\\input\\train\\train\\audio\\bed\\8b775397_nohash_1.wav',
#  '.\\input\\train\\train\\audio\\bed\\8bbd98d0_nohash_0.wav',
#  '.\\input\\train\\train\\audio\\bed\\8c3c4715_nohash_0.wav',
#  '.\\input\\train\\train\\audio\\bed\\8c3c4715_nohash_1.wav',
#  '.\\input\\train\\train\\audio\\bed\\8c4854bc_nohash_0.wav',
#  '.\\input\\train\\train\\audio\\bed\\8c4854bc_nohash_1.wav',
#  '.\\input\\train\\train\\audio\\bed\\8c4854bc_nohash_2.wav',
#  '.\\input\\train\\train\\audio\\bed\\8c7c9168_nohash_0.wav',
#  '.\\input\\train\\train\\audio\\bed\\8c7f81df_nohash_0.wav',
#  '.\\input\\train\\train\\audio\\bed\\8c888bbb_nohash_0.wav',
#  '.\\input\\train\\train\\audio\\bed\\8d5d076d_nohash_0.wav',
#  '.\\input\\train\\train\\audio\\bed\\8d8d9855_nohash_0.wav',
#  '.\\input\\train\\train\\audio\\bed\\8d8d9855_nohash_1.wav',
#  '.\\input\\train\\train\\audio\\bed\\8d8d9855_nohash_2.wav',
#  '.\\input\\train\\train\\audio\\bed\\8dd24423_nohash_0.wav',
#  '.\\input\\train\\train\\audio\\bed\\8dd24423_nohash_1.wav',
#  '.\\input\\train\\train\\audio\\bed\\8e05039f_nohash_0.wav',
#  '.\\input\\train\\train\\audio\\bed\\8ea22de7_nohash_0.wav',
#  '.\\input\\train\\train\\audio\\bed\\8eb4a1bf_nohash_0.wav',
#  '.\\input\\train\\train\\audio\\bed\\8ec6dab6_nohash_0.wav',
#  '.\\input\\train\\train\\audio\\bed\\8ec6dab6_nohash_1.wav',
#  '.\\input\\train\\train\\audio\\bed\\8f3f252c_nohash_0.wav',
#  '.\\input\\train\\train\\audio\\bed\\8f3f252c_nohash_1.wav',
#  '.\\input\\train\\train\\audio\\bed\\8f3f252c_nohash_2.wav',
#  '.\\input\\train\\train\\audio\\bed\\8f4c551f_nohash_0.wav',
#  '.\\input\\train\\train\\audio\\bed\\902258bb_nohash_0.wav',
#  '.\\input\\train\\train\\audio\\bed\\902258bb_nohash_1.wav',
#  '.\\input\\train\\train\\audio\\bed\\90804775_nohash_0.wav',
#  '.\\input\\train\\train\\audio\\bed\\90b0b91a_nohash_0.wav',
#  '.\\input\\train\\train\\audio\\bed\\91223b83_nohash_0.wav',
#  '.\\input\\train\\train\\audio\\bed\\918a2473_nohash_0.wav',
#  '.\\input\\train\\train\\audio\\bed\\9190045a_nohash_0.wav',
#  '.\\input\\train\\train\\audio\\bed\\919d3c0e_nohash_0.wav',
#  '.\\input\\train\\train\\audio\\bed\\91cdef62_nohash_0.wav',
#  '.\\input\\train\\train\\audio\\bed\\91cdef62_nohash_1.wav',
#  '.\\input\\train\\train\\audio\\bed\\91cdef62_nohash_2.wav',
#  '.\\input\\train\\train\\audio\\bed\\92037d73_nohash_0.wav',
#  '.\\input\\train\\train\\audio\\bed\\924c1a04_nohash_0.wav',
#  '.\\input\\train\\train\\audio\\bed\\924c1a04_nohash_1.wav',
#  '.\\input\\train\\train\\audio\\bed\\92a9c5e6_nohash_0.wav',
#  '.\\input\\train\\train\\audio\\bed\\92b2bf59_nohash_0.wav',
#  '.\\input\\train\\train\\audio\\bed\\92b2bf59_nohash_1.wav',
#  '.\\input\\train\\train\\audio\\bed\\92b2bf59_nohash_2.wav',
#  '.\\input\\train\\train\\audio\\bed\\92e17cc4_nohash_0.wav',
#  '.\\input\\train\\train\\audio\\bed\\92e17cc4_nohash_1.wav',
#  '.\\input\\train\\train\\audio\\bed\\937b433e_nohash_0.wav',
#  '.\\input\\train\\train\\audio\\bed\\93ec8b84_nohash_0.wav',
#  '.\\input\\train\\train\\audio\\bed\\93ec8b84_nohash_1.wav',
#  '.\\input\\train\\train\\audio\\bed\\94de6a6a_nohash_0.wav',
#  '.\\input\\train\\train\\audio\\bed\\94e6864f_nohash_0.wav',
#  '.\\input\\train\\train\\audio\\bed\\94e6864f_nohash_1.wav',
#  '.\\input\\train\\train\\audio\\bed\\94e6864f_nohash_2.wav',
#  '.\\input\\train\\train\\audio\\bed\\94e6864f_nohash_3.wav',
#  '.\\input\\train\\train\\audio\\bed\\94e6864f_nohash_4.wav',
#  '.\\input\\train\\train\\audio\\bed\\951cac20_nohash_0.wav',
#  '.\\input\\train\\train\\audio\\bed\\951cac20_nohash_1.wav',
#  '.\\input\\train\\train\\audio\\bed\\95218ce8_nohash_0.wav',
#  '.\\input\\train\\train\\audio\\bed\\95299b6c_nohash_0.wav',
#  '.\\input\\train\\train\\audio\\bed\\953fe1ad_nohash_0.wav',
#  '.\\input\\train\\train\\audio\\bed\\9587481f_nohash_0.wav',
#  '.\\input\\train\\train\\audio\\bed\\962f27eb_nohash_0.wav',
#  '.\\input\\train\\train\\audio\\bed\\9637f43f_nohash_0.wav',
#  '.\\input\\train\\train\\audio\\bed\\9637f43f_nohash_1.wav',
#  '.\\input\\train\\train\\audio\\bed\\964e8cfd_nohash_0.wav',
#  '.\\input\\train\\train\\audio\\bed\\96a48d28_nohash_0.wav',
#  '.\\input\\train\\train\\audio\\bed\\96ab6565_nohash_0.wav',
#  '.\\input\\train\\train\\audio\\bed\\96c67073_nohash_0.wav',
#  '.\\input\\train\\train\\audio\\bed\\96c67073_nohash_1.wav',
#  '.\\input\\train\\train\\audio\\bed\\9712cce0_nohash_0.wav',
#  '.\\input\\train\\train\\audio\\bed\\9799379a_nohash_0.wav',
#  '.\\input\\train\\train\\audio\\bed\\9799379a_nohash_1.wav',
#  '.\\input\\train\\train\\audio\\bed\\97addd88_nohash_0.wav',
#  '.\\input\\train\\train\\audio\\bed\\97ae8b25_nohash_0.wav',
#  '.\\input\\train\\train\\audio\\bed\\97ae8b25_nohash_1.wav',
#  '.\\input\\train\\train\\audio\\bed\\97e0c576_nohash_0.wav',
#  '.\\input\\train\\train\\audio\\bed\\97e0c576_nohash_1.wav',
#  '.\\input\\train\\train\\audio\\bed\\97e0c576_nohash_2.wav',
#  '.\\input\\train\\train\\audio\\bed\\97e0c576_nohash_3.wav',
#  '.\\input\\train\\train\\audio\\bed\\97f493b9_nohash_0.wav',
#  '.\\input\\train\\train\\audio\\bed\\97f4c236_nohash_0.wav',
#  '.\\input\\train\\train\\audio\\bed\\981e2a16_nohash_0.wav',
#  '.\\input\\train\\train\\audio\\bed\\981e2a16_nohash_1.wav',
#  '.\\input\\train\\train\\audio\\bed\\982babaf_nohash_0.wav',
#  '.\\input\\train\\train\\audio\\bed\\98447c43_nohash_0.wav',
#  '.\\input\\train\\train\\audio\\bed\\98447c43_nohash_1.wav',
#  '.\\input\\train\\train\\audio\\bed\\98582fee_nohash_0.wav',
#  '.\\input\\train\\train\\audio\\bed\\98582fee_nohash_1.wav',
#  '.\\input\\train\\train\\audio\\bed\\9886d8bf_nohash_0.wav',
#  '.\\input\\train\\train\\audio\\bed\\988e2f9a_nohash_0.wav',
#  '.\\input\\train\\train\\audio\\bed\\988e2f9a_nohash_1.wav',
#  '.\\input\\train\\train\\audio\\bed\\989a2213_nohash_0.wav',
#  '.\\input\\train\\train\\audio\\bed\\989a2213_nohash_1.wav',
#  '.\\input\\train\\train\\audio\\bed\\99081f4d_nohash_0.wav',
#  '.\\input\\train\\train\\audio\\bed\\997867e7_nohash_0.wav',
#  '.\\input\\train\\train\\audio\\bed\\99e6cab8_nohash_0.wav',
#  '.\\input\\train\\train\\audio\\bed\\99e6cab8_nohash_1.wav',
#  '.\\input\\train\\train\\audio\\bed\\99fad6a0_nohash_0.wav',
#  '.\\input\\train\\train\\audio\\bed\\99fad6a0_nohash_1.wav',
#  '.\\input\\train\\train\\audio\\bed\\9a356ab9_nohash_0.wav',
#  '.\\input\\train\\train\\audio\\bed\\9a3f97f8_nohash_0.wav',
#  '.\\input\\train\\train\\audio\\bed\\9a43b64b_nohash_0.wav',
#  '.\\input\\train\\train\\audio\\bed\\9a4d12fd_nohash_0.wav',
#  '.\\input\\train\\train\\audio\\bed\\9a4d12fd_nohash_1.wav',
#  '.\\input\\train\\train\\audio\\bed\\9a69672b_nohash_0.wav',
#  '.\\input\\train\\train\\audio\\bed\\9a7c1f83_nohash_0.wav',
#  '.\\input\\train\\train\\audio\\bed\\9a7c1f83_nohash_1.wav',
#  '.\\input\\train\\train\\audio\\bed\\9aa21fa9_nohash_0.wav',
#  '.\\input\\train\\train\\audio\\bed\\9aa5439d_nohash_0.wav',
#  ...]

# %%
ext = 'wav'
pat = r'.+/(\w+)/(\w+)/\w+\.' + ext + '$'
pat
# Out:
# '.+/(\\w+)/(\\w+)/\\w+\\.wav$'

# %%
labels = []

for fpath in fpaths:
    r = re.match(pat, fpath)
    #print(r)
    
    if r:
        labels.append(r.group(1))

print(labels)
# Out:
# []

# %%
pat = r'.+/(\w+\.' + ext + ')$'
fnames = []

for fpath in fpaths:
    r = re.match(pat, fpath)
    if r:
        fnames.append(r.group(1))
fnames
# Out:
# []

# %% [markdown]
# __pad_audio__ 는 16000(1초) 미만의 오디오를 0으로 패딩하여 모두 동일한 길이를 갖도록 합니다.
#
#
# __chop_audio__ 16000보다 큰 오디오(예: 백그라운드 노이즈 폴더의 wav 파일)를 16000으로 잘라냅니다. 또한 'num' 매개 변수가 지정된 하나의 큰 wav 파일로 여러 개의 청크를 생성합니다.
#
#
# __label_transform__ 레이블을 더미 값으로 변환합니다. 라벨을 예측하기 위해 softmax와 조합하여 사용합니다.

# %%
L = 16000
def pad_audio(samples):
    if len(samples) >= L: 
        return samples
    else: 
        return np.pad(samples, pad_width=(L - len(samples), 0), mode='constant', constant_values=(0, 0))

def chop_audio(samples, L=16000, num=20):
    for i in range(num):
        beg = np.random.randint(0, len(samples) - L)
        yield samples[beg: beg + L]

def label_transform(labels):
    nlabels = []
    for label in labels:
        if label == '_background_noise_':
            nlabels.append('silence')
        elif label not in legal_labels:
            nlabels.append('unknown')
        else:
            nlabels.append(label)
    return pd.get_dummies(pd.Series(nlabels))

# %%
beg = np.random.randint(0, 8)
beg
# Out:
# 3

# %% [markdown]
# 다음으로 위에서 선언한 함수를 사용하여 x_train과 y_train을 생성합니다.
# label_index는 팬더가 더미 값을 생성하기 위해 사용하는 인덱스이므로 나중에 사용하기 위해 저장해야 합니다.

# %%
labels, fnames = list_wavs_fname(train_data_path)
labels, fnames
# Out:
# .\input\train\train\audio
# ([], [])

# %%
labels, fnames = list_wavs_fname(train_data_path)

new_sample_rate = 8000
y_train = []
x_train = []

for label, fname in zip(labels, fnames):
    sample_rate, samples = wavfile.read(os.path.join(train_data_path, label, fname))
    samples = pad_audio(samples)
    
    if len(samples) > 16000:
        n_samples = chop_audio(samples)
    else: 
        n_samples = [samples]
    
    for samples in n_samples:
        resampled = signal.resample(samples, int(new_sample_rate / sample_rate * samples.shape[0]))
        _, _, specgram = log_specgram(resampled, sample_rate=new_sample_rate)
        y_train.append(label)
        x_train.append(specgram)
        
x_train = np.array(x_train)
x_train = x_train.reshape(tuple(list(x_train.shape) + [1]))
y_train = label_transform(y_train)
label_index = y_train.columns.values
y_train = y_train.values
y_train = np.array(y_train)
del labels, fnames
gc.collect()
# Out:
# .\input\train\train\audio
# C:\Users\HOME\AppData\Local\Temp/ipykernel_13572/2573807554.py:22: DeprecationWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   return pd.get_dummies(pd.Series(nlabels))
# 49

# %% [markdown]
# CNN은 다음과 같이 선언했습니다.
# 생성된 스펙그램은 모양(99, 81)이 되지만 Conv2D 레이어에 적합하려면 모양을 변경해야 합니다.

# %%
from tensorflow.keras.optimizers import Adam

input_shape = (99, 81, 1)
nclass = 12
inp = Input(shape=input_shape)
norm_inp = BatchNormalization()(inp)

img_1 = Convolution2D(8, kernel_size=2, activation=activations.relu)(norm_inp)
img_1 = Convolution2D(8, kernel_size=2, activation=activations.relu)(img_1)
img_1 = MaxPooling2D(pool_size=(2, 2))(img_1)
img_1 = Dropout(rate=0.2)(img_1)

img_1 = Convolution2D(16, kernel_size=3, activation=activations.relu)(img_1)
img_1 = Convolution2D(16, kernel_size=3, activation=activations.relu)(img_1)
img_1 = MaxPooling2D(pool_size=(2, 2))(img_1)
img_1 = Dropout(rate=0.2)(img_1)

img_1 = Convolution2D(32, kernel_size=3, activation=activations.relu)(img_1)
img_1 = MaxPooling2D(pool_size=(2, 2))(img_1)
img_1 = Dropout(rate=0.2)(img_1)

img_1 = Flatten()(img_1)

dense_1 = BatchNormalization()(Dense(128, activation=activations.relu)(img_1))
dense_1 = BatchNormalization()(Dense(128, activation=activations.relu)(dense_1))
dense_1 = Dense(nclass, activation=activations.softmax)(dense_1)

model = models.Model(inputs=inp, outputs=dense_1)
opt = Adam()

model.compile(optimizer=opt, loss=losses.binary_crossentropy)
model.summary()

x_train, x_valid, y_train, y_valid = train_test_split(x_train, y_train, test_size=0.1, random_state=2017)
model.fit(x_train, y_train, batch_size=16, validation_data=(x_valid, y_valid), epochs=3, shuffle=True, verbose=2)

model.save(os.path.join(model_path, 'cnn.model'))
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 99, 81, 1)]       0
#
#  batch_normalization (BatchN  (None, 99, 81, 1)        4
#  ormalization)
#
#  conv2d (Conv2D)             (None, 98, 80, 8)         40
#
#  conv2d_1 (Conv2D)           (None, 97, 79, 8)         264
#
#  max_pooling2d (MaxPooling2D  (None, 48, 39, 8)        0
#  )
#
#  dropout (Dropout)           (None, 48, 39, 8)         0
#
#  conv2d_2 (Conv2D)           (None, 46, 37, 16)        1168
#
#  conv2d_3 (Conv2D)           (None, 44, 35, 16)        2320
#
#  max_pooling2d_1 (MaxPooling  (None, 22, 17, 16)       0
#  2D)
#
#  dropout_1 (Dropout)         (None, 22, 17, 16)        0
#
#  conv2d_4 (Conv2D)           (None, 20, 15, 32)        4640
#
#  max_pooling2d_2 (MaxPooling  (None, 10, 7, 32)        0
#  2D)
#
#  dropout_2 (Dropout)         (None, 10, 7, 32)         0
#
#  flatten (Flatten)           (None, 2240)              0
#
#  dense (Dense)               (None, 128)               286848
#
#  batch_normalization_1 (Batc  (None, 128)              512
#  hNormalization)
#
#  dense_1 (Dense)             (None, 128)               16512
#
#  batch_normalization_2 (Batc  (None, 128)              512
#  hNormalization)
#
#  dense_2 (Dense)             (None, 12)                1548
#
# =================================================================
# Total params: 314,368
# Trainable params: 313,854
# Non-trainable params: 514
# _________________________________________________________________
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_13572/1023584884.py in <module>
#      27 model.summary()
#      28
# ---> 29 x_train, x_valid, y_train, y_valid = train_test_split(x_train, y_train, test_size=0.1, random_state=2017)
#      30 model.fit(x_train, y_train, batch_size=16, validation_data=(x_valid, y_valid), epochs=3, shuffle=True, verbose=2)
#      31
#
# ~\anaconda3\lib\site-packages\sklearn\model_selection\_split.py in train_test_split(test_size, train_size, random_state, shuffle, stratify, *arrays)
#    2173
#    2174     n_samples = _num_samples(arrays[0])
# -> 2175     n_train, n_test = _validate_shuffle_split(n_samples, test_size, train_size,
#    2176                                               default_test_size=0.25)
#    2177
#
# ~\anaconda3\lib\site-packages\sklearn\model_selection\_split.py in _validate_shuffle_split(n_samples, test_size, train_size, default_test_size)
#    1855
#    1856     if n_train == 0:
# -> 1857         raise ValueError(
#    1858             'With n_samples={}, test_size={} and train_size={}, the '
#    1859             'resulting train set will be empty. Adjust any of the '
#
# ValueError: With n_samples=0, test_size=0.1 and train_size=None, the resulting train set will be empty. Adjust any of the aforementioned parameters.

# %% [markdown]
# 테스트 데이터가 RAM에 들어가기에는 너무 커서 하나씩 처리해야 합니다.
# 생성기 test_data_generator는 CNN에 제공할 테스트 wav 파일 배치를 생성합니다.

# %%
def test_data_generator(batch=16):
    fpaths = glob(os.path.join(test_data_path, '*wav'))
    i = 0
    for path in fpaths:
        if i == 0:
            imgs = []
            fnames = []
        i += 1
        rate, samples = wavfile.read(path)
        samples = pad_audio(samples)
        resampled = signal.resample(samples, int(new_sample_rate / rate * samples.shape[0]))
        _, _, specgram = log_specgram(resampled, sample_rate=new_sample_rate)
        imgs.append(specgram)
        fnames.append(path.split('\\')[-1])
        if i == batch:
            i = 0
            imgs = np.array(imgs)
            imgs = imgs.reshape(tuple(list(imgs.shape) + [1]))
            yield fnames, imgs
    if i < batch:
        imgs = np.array(imgs)
        imgs = imgs.reshape(tuple(list(imgs.shape) + [1]))
        yield fnames, imgs
    raise StopIteration()

# %% [markdown]
# 교육받은 모형을 사용하여 검정 데이터의 레이블을 예측합니다.
# 그러나 Kaggle은 테스트 데이터를 제공하지 않기 때문에 다음 섹션은 여기에서 실행되지 않습니다.

# %%
exit() #delete this
del x_train, y_train
gc.collect()

index = []
results = []
for fnames, imgs in test_data_generator(batch=32):
    predicts = model.predict(imgs)
    predicts = np.argmax(predicts, axis=1)
    predicts = [label_index[p] for p in predicts]
    index.extend(fnames)
    results.extend(predicts)

df = pd.DataFrame(columns=['fname', 'label'])
df['fname'] = index
df['label'] = results
df.to_csv(os.path.join(out_path, 'sub.csv'), index=False)
