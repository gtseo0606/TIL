# %%
import pandas as pd

df = pd.read_csv("./Womens Clothing E-Commerce Reviews.csv")
df = df.drop(columns = ['Review Text', 'Title'])
df
# Out:
#        Unnamed: 0  Clothing ID  Age  Rating  Recommended IND  \
# 0               0          767   33       4                1
# 1               1         1080   34       5                1
# 2               2         1077   60       3                0
# 3               3         1049   50       5                1
# 4               4          847   47       5                1
# ...           ...          ...  ...     ...              ...
# 23481       23481         1104   34       5                1
# 23482       23482          862   48       3                1
# 23483       23483         1104   31       3                0
# 23484       23484         1084   28       3                1
# 23485       23485         1104   52       5                1
#
#        Positive Feedback Count   Division Name Department Name Class Name
# 0                            0       Initmates        Intimate  Intimates
# 1                            4         General         Dresses    Dresses
# 2                            0         General         Dresses    Dresses
# 3                            0  General Petite         Bottoms      Pants
# 4                            6         General            Tops    Blouses
# ...                        ...             ...             ...        ...
# 23481                        0  General Petite         Dresses    Dresses
# 23482                        0  General Petite            Tops      Knits
# 23483                        1  General Petite         Dresses    Dresses
# 23484                        2         General         Dresses    Dresses
# 23485                       22  General Petite         Dresses    Dresses
#
# [23486 rows x 9 columns]

# %%
from sklearn.preprocessing import StandardScaler

array = df['Age'].values.reshape(-1, 1)
standard_scaler = StandardScaler()
standard_scaler.fit(array)
df['Age'] = pd.Series(standard_scaler.transform(array).reshape(-1))
df
# Out:
#        Unnamed: 0  Clothing ID       Age  Rating  Recommended IND  \
# 0               0          767 -0.830549       4                1
# 1               1         1080 -0.749111       5                1
# 2               2         1077  1.368277       3                0
# 3               3         1049  0.553897       5                1
# 4               4          847  0.309583       5                1
# ...           ...          ...       ...     ...              ...
# 23481       23481         1104 -0.749111       5                1
# 23482       23482          862  0.391021       3                1
# 23483       23483         1104 -0.993425       3                0
# 23484       23484         1084 -1.237739       3                1
# 23485       23485         1104  0.716773       5                1
#
#        Positive Feedback Count   Division Name Department Name Class Name
# 0                            0       Initmates        Intimate  Intimates
# 1                            4         General         Dresses    Dresses
# 2                            0         General         Dresses    Dresses
# 3                            0  General Petite         Bottoms      Pants
# 4                            6         General            Tops    Blouses
# ...                        ...             ...             ...        ...
# 23481                        0  General Petite         Dresses    Dresses
# 23482                        0  General Petite            Tops      Knits
# 23483                        1  General Petite         Dresses    Dresses
# 23484                        2         General         Dresses    Dresses
# 23485                       22  General Petite         Dresses    Dresses
#
# [23486 rows x 9 columns]
