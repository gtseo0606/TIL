# %%
import pandas as pd 

df = pd.read_csv("./Womens Clothing E-Commerce Reviews.csv")
df = df.drop(columns = ['Review Text', 'Title'])
df
# Out:
#        Unnamed: 0  Clothing ID  Age  Rating  Recommended IND  \
# 0               0          767   33       4                1
# 1               1         1080   34       5                1
# 2               2         1077   60       3                0
# 3               3         1049   50       5                1
# 4               4          847   47       5                1
# ...           ...          ...  ...     ...              ...
# 23481       23481         1104   34       5                1
# 23482       23482          862   48       3                1
# 23483       23483         1104   31       3                0
# 23484       23484         1084   28       3                1
# 23485       23485         1104   52       5                1
#
#        Positive Feedback Count   Division Name Department Name Class Name
# 0                            0       Initmates        Intimate  Intimates
# 1                            4         General         Dresses    Dresses
# ...

# %%
df.groupby('Rating')['Age'].agg(**{'mean_age':'mean'})
# Out:
#          mean_age
# Rating
# 1       43.693587
# 2       42.622364
# 3       42.158481
# 4       42.887532
# 5       43.583124

# %%
df.groupby('Rating')['Age'].agg(**{'mode_Age':lambda x:x.mode()})
# Out:
#         mode_Age
# Rating
# 1             35
# 2             35
# 3             39
# 4             39
# 5             39

# %%
df.groupby('Rating').agg(**{'min_age':pd.NamedAgg(column='Age', aggfunc='min'),
                           'max_age':pd.NamedAgg(column='Age', aggfunc='max'),
                           'mean_positive_feedback':pd.NamedAgg(column='Positive Feedback Count', aggfunc='mean'),
                           'median_positive_feedback':pd.NamedAgg(column='Positive Feedback Count', aggfunc='median'),
                           })
# Out:
#         min_age  max_age  mean_positive_feedback  median_positive_feedback
# Rating
# 1            19       94                3.459620                         1
# 2            19       91                3.325879                         1
# 3            19       91                3.145246                         1
# 4            18       99                2.405554                         1
# 5            18       99                2.299749                         1
